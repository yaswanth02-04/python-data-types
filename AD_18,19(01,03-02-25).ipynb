# %% [markdown]
# <a href="https://colab.research.google.com/github/yaswanth02-04/python-data-types/blob/main/AD_18%2C19(01%2C03-02-25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv(r"/content/NewspaperData.csv")
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.shape
# Out:
# (34, 3)

# %%
data.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
data.sample(10)
# Out:
#                    Newspaper     daily    sunday
# 14              Miami Herald   444.581   553.479
# 11          Kansas City Star   288.571   423.305
# 27       Rocky Mountain News   374.009   432.502
# 13         Los Angeles Times  1164.388  1531.527
# 1               Boston Globe   516.981   798.298
# 24        Portland Oregonian   337.672   440.923
# 15  Minneapolis Star Tribune   412.871   685.975
# 17       New York Daily News   781.796   983.240
# 29   San Francisco Chronicle   570.364   704.322
# 12   Los Angeles Daily  News   185.736   202.614

# %%
data.sum()
# Out:
# Newspaper    Baltimore SunBoston GlobeBoston HeraldCharlott...
# daily                                                14652.724
# sunday                                               20100.882
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data.drop('Newspaper',axis=1).corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data['sunday'])
plt.show()
# Out:
# <ipython-input-16-11ebaaff228a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sunday'])

# %%
import statsmodels.formula.api as smf
model=smf.ols('sunday~daily',data=data).fit()

# %%
sns.regplot(x="daily",y="sunday",data=data,ci=None);

# %%
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
#coefficients
model.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.9180596895873295, 0.9154990548869336)
